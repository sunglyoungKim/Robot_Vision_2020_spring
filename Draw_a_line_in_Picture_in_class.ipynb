# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
imgfile_Pepper = './data/Peppers.tiff'

im_Pepper = cv2.imread(imgfile_Pepper)

converted_lena= cv2.cvtColor(im_Pepper, cv2.COLOR_BGR2RGB) # convrt color bgr to rgb
fig= plt.figure(figsize=(8,8))
plt.imshow(converted_lena)

# %% [markdown]
# ## Can you draw the line between two points?

# %%
p0 = [30, 100]
p1 = [100, 150]

# %%
## Please Try it by your self

# %% [markdown]
# ## I will use two functions that I previous used
